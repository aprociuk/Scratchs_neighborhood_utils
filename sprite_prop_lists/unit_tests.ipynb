# %%
import os, sys


#############################################
# Initial setup                             #
#############################################

# Repository name (used in path buildin):
repo_name='Scratchs_neighborhood_utils'
repo_path = os.path.join(os.getcwd().split(repo_name)[0],
                         repo_name
                        )

sys.path.insert(0,f"{repo_path}")

from _000_system_include.global_functions import global_parameters
from sprite_prop_lists.step01_pull_data import ( 
    build_sprite_tables,
    archive_files,
    sprite_out,
    build_prop_tables
)
from sprite_prop_lists.step02_analyze_transform import create_sprite_prop_roadmap

def main():
    mypath = "/Users/aprociuk/code/scratch/kindred_kitty/code/master_list/from_project/1.9.9"
    myfiles=[
              'prop variable names.txt',
              'prop variable values.txt',
              'sprite variable names.txt',
              'sprite variable values.txt'
            ]
        
    #Pull parameters for module
    gparams = global_parameters()
    
    # test build_sprite_tables
    #(
    #    status_str, 
    #    uber_sprite_list, 
    #    plain_sprite_list, 
    #    uber_xwalk, 
    #    sprite_costumes_main,
    #    landmarks_xwalk
    #) = build_sprite_tables(mypath, myfiles[2:], gparams)
    #
    #sprite_out(uber_sprite_list, plain_sprite_list, mypath, myfiles[2:])
    #
    #(
    #    status_str, 
    #    plain_prop_list 
    #) = build_prop_tables(mypath, myfiles[0:2], gparams)
    #
    status_str, sprite_prop_roadmap = create_sprite_prop_roadmap(gparams)
    print("\nsprite_prop_roadmap:")
    print(sprite_prop_roadmap)
    print(status_str)
    

main()
